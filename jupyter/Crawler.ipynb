# %%
# import urllib.request
import os
import sys
import requests

# %%
url= 'https://www.baidu.com'
kv={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36'}
try:
    r = requests.get(url,headers=kv)
    r.raise_for_status()
    print(r.status_code)
    print(r.encoding)
    print(r.apparent_encoding)
    print(r.request.headers)
except requests.HTTPError:
    print(type(requests.HTTPError))
# Out:
# 200
# ISO-8859-1
# utf-8
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
# response_get = requests.get("http://www.baidu.com")
# print(response_get.status_code)
# print(type(response_get))
# print(response_get.encoding)
# response_head=requests.head('http://www.baidu.com')
# print('response_head.text:',response_head.text)
# print('response_get.text:',response_get.text)
# print(response.apparent_encoding)
# response.encoding =response.apparent_encoding
# print(response.text).
payload = bytes("k1=v1&k2=k2&k3=v3&k3=vv3", encoding='utf8')
params="k1=v1&k2=水电费&k3=v3&k3=vv3"
# params={'k1': 'v1', 'k2': '水电费'}
# params=bytes("k1=v1&k2='水电费'&k3=v3&k3=vv3", encoding='utf8')
# pro = {'User-Agent':'chrome/10'}
ret = requests.get("http://httpbin.org/get", params=payload)
print(ret.request.url)
# Out:
# http://httpbin.org/get?k1=v1&k2=k2&k3=v3&k3=vv3

# %%
url='https://item.jd.com/2967929.html'
try:
    r = requests.get(url)
    r.raise_for_status()
    r.status_code
    print(r.encoding)
    print(r.apparent_encoding)
except:
    print('Error')
# Out:
# gbk
# GB2312
# {'User-Agent': 'python-requests/2.19.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
url='http://www.baidu.com/'
kv={'user-agent':'Mozilla/5.0'}
try:
    r = requests.get(url,headers=kv)
    r.raise_for_status()
    print(r.status_code)
    print(r.encoding)
    print(r.apparent_encoding)
    print(r.request.headers)
#     print(r.text[1000:1500])
except:
    print('Error')
# Out:
# 200
# ISO-8859-1
# utf-8
# {'user-agent': 'Mozilla/5.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# 	<link rel="dns-prefetch" href="//t1.baidu.com"/>
# 	<link rel="dns-prefetch" href="//t2.baidu.com"/>
# 	<link rel="dns-prefetch" href="//t3.baidu.com"/>
# 	<link rel="dns-prefetch" href="//t10.baidu.com"/>
# 	<link rel="dns-prefetch" href="//t11.baidu.com"/>
# 	<link rel="dns-prefetch" href="//t12.baidu.com"/>
# 	<link rel="dns-prefetch" href="//b1.bdstatic.com"/>
#
#     <title>ç¾åº¦ä¸ä¸ï¼ä½ å°±ç¥é</title>
#
#
# <style id="css_index" index="index" type="text/css">html,body{height:100%}
# html{overf

# %% [markdown]
# # 百度关键词提交
# www.baidu.com/s?wd=keyword
# www.so.com/s?q=keyword

# %%
url = 'http://www.baidu.com/s'
params = {'wd':'Python'}
try:
    r = requests.get(url,params=params)
    r.raise_for_status()
    print(r.request.url)
    print(r.status_code)
    print(len(r.text)) 
except:
    print('Error')
# Out:
# http://www.baidu.com/s?wd=Python
# 200
# 253384

# %% [markdown]
# # 图片的爬取和存储

# %%
path ='D:/data/requests.jpg'
url = 'https://images-na.ssl-images-amazon.com/images/I/41C9U6RDdSL._SX340_BO1,204,203,200_.jpg'
try:
    r=requests.get(url)
    r.raise_for_status()
    print(r.status_code)
    with open(path,'wb') as f:
        f.write(r.content)
except:
    print(r.text[200:1200])
    print("Error")
# Out:
# 200

# %% [markdown]
# # ip地址的归属地查询

# %%
url = 'http://m.ip138.com/ip.asp?'
kv = {'ip':'202.112.208.3'}
try:
    r = requests.get(url,params)
    r.raise_for_status()
    print(r.status_code)
#     print(r.text[-700:-150])
except:
    print('Error')
# Out:
# Error

# %% [markdown]
# # beautiful soup 库

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://m.ip138.com/ip.asp?'
params = {'ip': '202.112.208.3'}
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36'}
try:
    r = requests.get(url, params=params, headers=headers)
    demo = r.text
    soup = BeautifulSoup(demo, 'html.parser')
    print(soup.title)
#     print(soup.prettify)
    print(soup.li.name)
    print(soup.li.parent.name)
    print(soup.li.parent.parent.name)
    tag = soup.li
    print(tag)
    print(tag.name)
    print(tag.attrs)
    print(tag.string)
    print(tag.comment)
    print('None' if None else 'Some')
    print(tag.contents)
except requests.HTTPError as err:
    print(err)
# Out:
# <title>IP地址在线查询 m.ip138.com 查询网</title>
# li
# ul
# div
# <li><a href="/ip.html">iP查询</a></li>
# li
# {}
# iP查询
# None
# Some
# [<a href="/ip.html">iP查询</a>]

# %% [markdown]
# # html遍历方法
# ##### html->head /title
# #####        body->p/a
# ## 三种遍历方法：上行，下行，平行 遍历
# ## 下行遍历
# ### .contents 子节点的列表，将标签 <tag>所有儿子节点存入列表
#     .children 子节点的迭代类型,迭代器，与.contents 类似，用于循环遍历儿子节点,for in 迭代
#     .descendants子孙节点的迭代类型，包含所有子孙节点，用于循环遍历

# %%
url ='http://www.baidu.com'
r =requests.get(url)
r.encoding = r.apparent_encoding
demo = r.text
soup = BeautifulSoup(demo,'html.parser')
print(soup.head.contents)
next(soup.head.descendants)
# for child in soup.head.descendants:
#     print(child)
# Out:
# [<meta content="text/html;charset=utf-8" http-equiv="content-type"/>, <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>, <meta content="always" name="referrer"/>, <link href="http://s1.bdstatic.com/r/www/cache/bdorz/baidu.min.css" rel="stylesheet" type="text/css"/>, <title>百度一下，你就知道</title>]
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>

# %% [markdown]
# ## 上行遍历
# ### .parent 节点的父亲类型
#     .parents 先辈标签的迭代类型，用于循环遍历先辈节点

# %%
soup.title.parent
# Out:
# <head><meta content="text/html;charset=utf-8" http-equiv="content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="always" name="referrer"/><link href="http://s1.bdstatic.com/r/www/cache/bdorz/baidu.min.css" rel="stylesheet" type="text/css"/><title>百度一下，你就知道</title></head>

# %% [markdown]
# ## 平行遍历
# ### .next_sibling 下一个平行节点标签
# .previous_sibling 返回按照html文本顺序的上一个平行节点标签
# .next-sibling 迭代类型，后续所有平行节点标签
# .previous_siblings 迭代类型，前续所有平行节点标签

# %%
soup.meta.next_sibling
print(soup.li.parent.contents)
print(soup.li)
print(soup.li.next_sibling.next_sibling)
# Out:
# ['\n', <li><a href="/ip.html">iP查询</a></li>, '\n', <li><a href="/mobile.html">手机号码归属地查询</a></li>, '\n', <li><a href="/huilv/">汇率查询</a></li>, '\n', <li><a href="/youbian/">邮编区号查询</a></li>, '\n', <li><a href="/kuaidi/">快递查询</a></li>, '\n', <li><a href="http://qq.ip138.com/tianqi/">天气预报查询</a></li>, '\n', <li><a href="http://qq.ip138.com/shenfenzheng/">身份证号码查询</a></li>, '\n', <li><a href="http://qq.ip138.com/huoche/">列车时刻表查询</a></li>, '\n', <li><a href="http://qq.ip138.com/daishoudian/mobile.htm">火车票代售点查询</a></li>, '\n']
# <li><a href="/ip.html">iP查询</a></li>
# <li><a href="/mobile.html">手机号码归属地查询</a></li>

# %% [markdown]
# # 基于bs4库的html的格式化和编码
# ## 让html内容更友好地显示

# %%
# print(soup.prettify())

# %% [markdown]
# ## 信息的标记

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url ='http://www.xicidaili.com/wt/'
headers= {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36'}
try:
    r = requests.request('get',url,headers=headers,proxies = None)
    r.raise_for_status()
    r.encoding  = r.apparent_encoding
    demo = r.text
    soup  = BeautifulSoup(r.text,'html.parser')
    # for tag in soup.find_all(['a','body']):
    #     print(tag.string)
#     print(soup)
    for tag in soup.find_all(name = 'td',):
        print(tag)
except:
    print('Error')
    print(r.status_code)
# Out:
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>118.190.95.35</td>
# <td>9001</td>
# <td>
# <a href="/2018-06-22/guangxi">广西</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.052秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.01秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>117天</td>
# <td>18-10-17 18:12</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>61.135.217.7</td>
# <td>80</td>
# <td>
# <a href="/2016-05-13/beijing">北京</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.324秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.064秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>887天</td>
# <td>18-10-17 18:12</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>222.221.11.119</td>
# <td>3128</td>
# <td>
# <a href="/2018-08-04/yunnan">云南昆明</a>
# </td>
# <td class="country">透明</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.265秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.053秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>73天</td>
# <td>18-10-17 18:07</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>218.14.115.211</td>
# <td>3128</td>
# <td>
# <a href="/2018-06-02/guangdong">广东惠州</a>
# </td>
# <td class="country">透明</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.285秒">
# <div class="bar_inner fast" style="width:91%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.057秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>136天</td>
# <td>18-10-17 18:00</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>180.118.241.193</td>
# <td>808</td>
# <td>
# <a href="/2017-05-30/jiangsu">江苏镇江</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="7.205秒">
# <div class="bar_inner slow" style="width:69%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="1.441秒">
# <div class="bar_inner medium" style="width:81%">
# </div>
# </div>
# </td>
# <td>505天</td>
# <td>18-10-17 18:00</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>175.148.78.174</td>
# <td>1133</td>
# <td>
# <a href="/2018-10-15/liaoning">辽宁葫芦岛</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.231秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.046秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>2天</td>
# <td>18-10-17 18:00</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>110.40.13.5</td>
# <td>80</td>
# <td>
# <a href="/2018-09-27/beijing">北京</a>
# </td>
# <td class="country">透明</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.015秒">
# <div class="bar_inner fast" style="width:89%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.003秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>20天</td>
# <td>18-10-17 17:51</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>115.46.98.44</td>
# <td>8123</td>
# <td>
# <a href="/2018-02-24/guangxi">广西南宁</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="4.444秒">
# <div class="bar_inner medium" style="width:85%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.888秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>234天</td>
# <td>18-10-17 17:22</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>125.46.0.62</td>
# <td>53281</td>
# <td>
# <a href="/2017-08-16/henan">河南济源</a>
# </td>
# <td class="country">透明</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.1秒">
# <div class="bar_inner fast" style="width:89%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.02秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>427天</td>
# <td>18-10-17 17:16</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>112.90.60.226</td>
# <td>8080</td>
# <td>
# <a href="/2018-09-03/guangdong">广东珠海</a>
# </td>
# <td class="country">透明</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.22秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.044秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>43天</td>
# <td>18-10-17 17:16</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>114.249.112.57</td>
# <td>9000</td>
# <td>
# <a href="/2018-10-17/beijing">北京</a>
# </td>
# <td class="country">透明</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="6.639秒">
# <div class="bar_inner slow" style="width:54%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="1.327秒">
# <div class="bar_inner medium" style="width:85%">
# </div>
# </div>
# </td>
# <td>14分钟</td>
# <td>18-10-17 17:01</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>123.161.21.200</td>
# <td>9797</td>
# <td>
# <a href="/2018-10-17/henan">河南安阳</a>
# </td>
# <td class="country">透明</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="3.621秒">
# <div class="bar_inner medium" style="width:82%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.724秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>10分钟</td>
# <td>18-10-17 16:40</td>
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>221.13.137.202</td>
# <td>31449</td>
# <td>
# <a href="/2018-10-05/henan">河南洛阳</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0